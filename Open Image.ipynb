# %%
from PIL import Image

# %%
pic = Image.open('Apple.png')

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=320x96 at 0x7F7D27E052E0>

# %%
 pic.size
# Out:
# (320, 96)

# %%
pic.filename
# Out:
# 'Apple.png'
